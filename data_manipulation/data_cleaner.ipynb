# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import json

# %% [markdown]
# # Manipulating the data

# %% [markdown]
# ## Read json file

# %%
# Path: data/fragances.json
# Opening JSON file
f = open("../data/fragances.json", encoding="utf8")

# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
for i in range(len(data)):
    data[i] = flatten_json(data[i])
df = pd.DataFrame(data)
df.head()
# Out:
#                    _id_$oid  idNumber  \
# 0  6536bfd623ce6e4d819f5f06         1
# 1  6536c06c23ce6e4d819f5f0a         2
# 2  6536c06d23ce6e4d819f5f0c         3
# 3  6536c06e23ce6e4d819f5f0e         4
# 4  6536c06f23ce6e4d819f5f10         5
#
#                                                 name  designer  \
# 0  Couture! Moschino perfume - a fragrance for wo...  Moschino
# 1  Friends Men Moschino cologne - a fragrance for...  Moschino
# 2  Moschino Moschino perfume - a fragrance for wo...  Moschino
# 3  Moschino Funny! Moschino perfume - a fragrance...  Moschino
# 4  Moschino Pour Homme Moschino cologne - a fragr...  Moschino
#
#   official_gender  rating  votes  seasons_winter  seasons_summer  \
# 0       for women    4.21   1627              38              14
# 1         for men    3.92    499               4              19
# 2       for women    3.98   1267              43               9
# 3       for women    3.98   6375               7              74
# 4         for men    4.34    256               9               2
#
#    seasons_autumn  ...  base_notes_17  base_notes_18  base_notes_19  \
# 0              45  ...            NaN            NaN            NaN
# 1               6  ...            NaN            NaN            NaN
# 2              42  ...            NaN            NaN            NaN
# 3               9  ...            NaN            NaN            NaN
# 4              10  ...            NaN            NaN            NaN
#
#    middle_notes_16  base_notes_20  base_notes_21  base_notes_22  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
#
#    base_notes_23  top_notes_14  top_notes_15
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
#
# [5 rows x 106 columns]

# %%
df.to_csv('../data/fragances.csv', index=False)

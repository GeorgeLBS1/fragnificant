# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns

# %% [markdown]
# # Manipulating the data

# %% [markdown]
# ## Read json file

# %%
datos = pd.read_csv('../data/fragances.csv')
datos.head(10)
# Out:
# C:\Users\dmont\AppData\Local\Temp\ipykernel_17920\1840697606.py:1: DtypeWarning: Columns (58,59,60,61,62,75,76,77,78,79,92,93,94,95,96,97,98,99,100,101,102,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos = pd.read_csv('../data/fragances.csv')
#                         _id  idNumber  \
# 0  6536bfd623ce6e4d819f5f06         1
# 1  6536c06c23ce6e4d819f5f0a         2
# 2  6536c06d23ce6e4d819f5f0c         3
# 3  6536c06e23ce6e4d819f5f0e         4
# 4  6536c06f23ce6e4d819f5f10         5
# 5  6536c06f23ce6e4d819f5f12         6
# 6  6536c07023ce6e4d819f5f14         7
# 7  6536c07123ce6e4d819f5f16         8
# 8  6536c07223ce6e4d819f5f18         9
# 9  6536c07323ce6e4d819f5f1a        10
#
#                                                 name  designer  \
# 0  Couture! Moschino perfume - a fragrance for wo...  Moschino
# 1  Friends Men Moschino cologne - a fragrance for...  Moschino
# 2  Moschino Moschino perfume - a fragrance for wo...  Moschino
# 3  Moschino Funny! Moschino perfume - a fragrance...  Moschino
# 4  Moschino Pour Homme Moschino cologne - a fragr...  Moschino
# 5  OH! De Moschino Moschino perfume - a fragrance...  Moschino
# 6  Uomo? Moschino cologne - a fragrance for men 1998  Moschino
# 7  Cheap &amp;amp; Chic Moschino perfume - a frag...  Moschino
# 8  Cheap &amp;amp; Chic Chic Petals Moschino perf...  Moschino
# 9  Cheap &amp;amp; Chic I Love Love Moschino perf...  Moschino
#
#   official_gender  rating  votes  seasons.winter  seasons.summer  \
# 0       for women    4.21   1627              38              14
# 1         for men    3.92    499               4              19
# 2       for women    3.98   1267              43               9
# 3       for women    3.98   6375               7              74
# 4         for men    4.34    256               9               2
# 5       for women    3.82    667               2              13
# 6         for men    4.08   2185              21              61
# 7       for women    3.80   4520              30              29
# 8       for women    3.67   1268               0              11
# 9       for women    3.92  11235               9              90
#
#    seasons.autumn  ...  base_notes[16]  base_notes[17]  base_notes[18]  \
# 0              45  ...             NaN             NaN             NaN
# 1               6  ...             NaN             NaN             NaN
# 2              42  ...             NaN             NaN             NaN
# 3               9  ...             NaN             NaN             NaN
# 4              10  ...             NaN             NaN             NaN
# 5               8  ...             NaN             NaN             NaN
# 6              48  ...             NaN             NaN             NaN
# 7              37  ...             NaN             NaN             NaN
# 8               3  ...             NaN             NaN             NaN
# 9              18  ...             NaN             NaN             NaN
#
#    base_notes[19]  base_notes[20]  base_notes[21]  base_notes[22]  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
# 6             NaN             NaN             NaN             NaN
# 7             NaN             NaN             NaN             NaN
# 8             NaN             NaN             NaN             NaN
# 9             NaN             NaN             NaN             NaN
#
#    base_notes[23]  link  img
# 0             NaN   NaN  NaN
# 1             NaN   NaN  NaN
# 2             NaN   NaN  NaN
# 3             NaN   NaN  NaN
# 4             NaN   NaN  NaN
# 5             NaN   NaN  NaN
# 6             NaN   NaN  NaN
# 7             NaN   NaN  NaN
# 8             NaN   NaN  NaN
# 9             NaN   NaN  NaN
#
# [10 rows x 106 columns]

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
for i in range(len(data)):
    data[i] = flatten_json(data[i])
df = pd.DataFrame(data)
df.head()

# %%
df.to_csv('../data/fragances.csv', index=False)
